# %%
import numpy as np

import matplotlib.pyplot as plt
import matplotlib as mpl
from sklearn import datasets


import seaborn as sns  

import tensorflow as tf
from tensorflow import keras
from keras import layers, Model, optimizers, regularizers
from keras.utils import np_utils
#from keras.datasets import mnist
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
# %matplotlib inline

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %%
plt.figure(figsize=(7, 4), dpi=100)
for i in range(100):
  plt.subplot(10,10,i+1)
  plt.imshow(X_train[i,:].reshape([28,28]), cmap='gray')
  plt.axis('off')
plt.show()

# %%
# Visualisation de la répartition des labels
sns.set()
ax = sns.countplot(y_train)
# Out:
# C:\Users\bahas\Anaconda3\envs\Python et R\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Visualisation de la répartition des labels
sns.set()
ax = sns.countplot(y_test)
# Out:
# C:\Users\bahas\Anaconda3\envs\Python et R\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# 6. Explorez et testez différentes combinaisons d’architectures et d'hyper-paramètres du PMC. Prenez soin de comparer vos modèles et notez les meilleurs résultats.

# %%
model = Sequential()

model.add(Dense(10, input_shape=(784,)))
model.add(Dense(15, activation='sigmoid'))
model.add(Dense(10, activation='sigmoid'))

# Impression d'une description du réseau
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                7850
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                165
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                160
# =================================================================
# Total params: 8,175
# Trainable params: 8,175
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model1 = model.fit(X_train, y_train, epochs=50, batch_size= 32 , validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.0498 - accuracy: 0.7829 - val_loss: 0.5113 - val_accuracy: 0.8875
# Epoch 2/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4249 - accuracy: 0.8949 - val_loss: 0.3493 - val_accuracy: 0.9061
# Epoch 3/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3306 - accuracy: 0.9092 - val_loss: 0.3008 - val_accuracy: 0.9142
# Epoch 4/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2899 - accuracy: 0.9189 - val_loss: 0.2761 - val_accuracy: 0.9203
# Epoch 5/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2662 - accuracy: 0.9247 - val_loss: 0.2638 - val_accuracy: 0.9239
# Epoch 6/50
# 1875/1875 [==============================] - 2s 887us/step - loss: 0.2497 - accuracy: 0.9282 - val_loss: 0.2477 - val_accuracy: 0.9276
# Epoch 7/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2377 - accuracy: 0.9318 - val_loss: 0.2447 - val_accuracy: 0.9270
# Epoch 8/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2288 - accuracy: 0.9350 - val_loss: 0.2436 - val_accuracy: 0.9283
# Epoch 9/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2218 - accuracy: 0.9360 - val_loss: 0.2358 - val_accuracy: 0.9295
# Epoch 10/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2158 - accuracy: 0.9377 - val_loss: 0.2318 - val_accuracy: 0.9308
# Epoch 11/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2099 - accuracy: 0.9396 - val_loss: 0.2331 - val_accuracy: 0.9300
# Epoch 12/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2061 - accuracy: 0.9414 - val_loss: 0.2286 - val_accuracy: 0.9316
# Epoch 13/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2031 - accuracy: 0.9413 - val_loss: 0.2254 - val_accuracy: 0.9325
# Epoch 14/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1987 - accuracy: 0.9436 - val_loss: 0.2261 - val_accuracy: 0.9309
# Epoch 15/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1963 - accuracy: 0.9438 - val_loss: 0.2284 - val_accuracy: 0.9300
# Epoch 16/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1939 - accuracy: 0.9443 - val_loss: 0.2306 - val_accuracy: 0.9282
# Epoch 17/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1911 - accuracy: 0.9452 - val_loss: 0.2253 - val_accuracy: 0.9316
# Epoch 18/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1887 - accuracy: 0.9459 - val_loss: 0.2273 - val_accuracy: 0.9313
# Epoch 19/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1866 - accuracy: 0.9458 - val_loss: 0.2247 - val_accuracy: 0.9333
# Epoch 20/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1845 - accuracy: 0.9463 - val_loss: 0.2265 - val_accuracy: 0.9312
# Epoch 21/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1828 - accuracy: 0.9465 - val_loss: 0.2266 - val_accuracy: 0.9326
# Epoch 22/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1820 - accuracy: 0.9477 - val_loss: 0.2232 - val_accuracy: 0.9326
# Epoch 23/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1791 - accuracy: 0.9477 - val_loss: 0.2249 - val_accuracy: 0.9327
# Epoch 24/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1786 - accuracy: 0.9479 - val_loss: 0.2340 - val_accuracy: 0.9287
# Epoch 25/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1764 - accuracy: 0.9487 - val_loss: 0.2230 - val_accuracy: 0.9342
# Epoch 26/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1752 - accuracy: 0.9491 - val_loss: 0.2301 - val_accuracy: 0.9309
# Epoch 27/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1736 - accuracy: 0.9499 - val_loss: 0.2258 - val_accuracy: 0.9344
# Epoch 28/50
# 1875/1875 [==============================] - 2s 988us/step - loss: 0.1723 - accuracy: 0.9499 - val_loss: 0.2250 - val_accuracy: 0.9347
# Epoch 29/50
# 1875/1875 [==============================] - 1s 795us/step - loss: 0.1718 - accuracy: 0.9499 - val_loss: 0.2269 - val_accuracy: 0.9322
# Epoch 30/50
# 1875/1875 [==============================] - 2s 989us/step - loss: 0.1699 - accuracy: 0.9505 - val_loss: 0.2224 - val_accuracy: 0.9344
# Epoch 31/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1696 - accuracy: 0.9501 - val_loss: 0.2305 - val_accuracy: 0.9301
# Epoch 32/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1671 - accuracy: 0.9514 - val_loss: 0.2269 - val_accuracy: 0.9330
# Epoch 33/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1671 - accuracy: 0.9514 - val_loss: 0.2280 - val_accuracy: 0.9326
# Epoch 34/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1669 - accuracy: 0.9507 - val_loss: 0.2242 - val_accuracy: 0.9339
# Epoch 35/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1654 - accuracy: 0.9520 - val_loss: 0.2300 - val_accuracy: 0.9318
# Epoch 36/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1649 - accuracy: 0.9515 - val_loss: 0.2307 - val_accuracy: 0.9314
# Epoch 37/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1635 - accuracy: 0.9519 - val_loss: 0.2303 - val_accuracy: 0.9340
# Epoch 38/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1637 - accuracy: 0.9515 - val_loss: 0.2291 - val_accuracy: 0.9342
# Epoch 39/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1621 - accuracy: 0.9522 - val_loss: 0.2290 - val_accuracy: 0.9336
# Epoch 40/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1613 - accuracy: 0.9522 - val_loss: 0.2304 - val_accuracy: 0.9337
# Epoch 41/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1610 - accuracy: 0.9528 - val_loss: 0.2273 - val_accuracy: 0.9337
# Epoch 42/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1594 - accuracy: 0.9532 - val_loss: 0.2283 - val_accuracy: 0.9337
# Epoch 43/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1598 - accuracy: 0.9528 - val_loss: 0.2300 - val_accuracy: 0.9349
# Epoch 44/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1581 - accuracy: 0.9540 - val_loss: 0.2314 - val_accuracy: 0.9340
# Epoch 45/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1584 - accuracy: 0.9524 - val_loss: 0.2331 - val_accuracy: 0.9329
# Epoch 46/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1570 - accuracy: 0.9537 - val_loss: 0.2320 - val_accuracy: 0.9324
# Epoch 47/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1569 - accuracy: 0.9537 - val_loss: 0.2322 - val_accuracy: 0.9344
# Epoch 48/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1556 - accuracy: 0.9537 - val_loss: 0.2296 - val_accuracy: 0.9347
# Epoch 49/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1550 - accuracy: 0.9532 - val_loss: 0.2399 - val_accuracy: 0.9311
# Epoch 50/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1548 - accuracy: 0.9543 - val_loss: 0.2308 - val_accuracy: 0.9327

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 0s 905us/step - loss: 0.2308 - accuracy: 0.9327
# [0.23078952729701996, 0.932699978351593]

# %%
y_predicted = model.predict(X_test)
y_predicted_labels = [np.argmax(i) for i in y_predicted]

cm = tf.math.confusion_matrix(labels=y_test, predictions=y_predicted_labels)

import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(66.5, 0.5, 'Truth')

# %%
fig = plt.figure()
plt.subplot(2,1,1)
plt.plot(model1.history['accuracy'])
plt.plot(model1.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

plt.subplot(2,1,2)
plt.plot(model1.history['loss'])
plt.plot(model1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.tight_layout()

# %% [markdown]
# 7. Après l’utilisation d’une couche dense, les données sont transformées. Cela à souvent pour effet de produire des valeurs totalement dispersées. Remédiez à ce problème en ajoutant une couche de normalisation.

# %%
model = Sequential()

model.add(Dense(100, input_shape=(784,)))
#model.add(BatchNormalization())
#layer = Normalization()
model.add(Dense(15, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(10, activation='sigmoid'))
#model.add(BatchNormalization())

# Impression d'une description du réseau
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 100)               78500
# _________________________________________________________________
# dense_4 (Dense)              (None, 15)                1515
# _________________________________________________________________
# batch_normalization (BatchNo (None, 15)                60
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                160
# =================================================================
# Total params: 80,235
# Trainable params: 80,205
# Non-trainable params: 30
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model2 = model.fit(X_train, y_train, epochs=50, batch_size= 32 , validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.6814 - accuracy: 0.8542 - val_loss: 0.2843 - val_accuracy: 0.9197
# Epoch 2/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2835 - accuracy: 0.9163 - val_loss: 0.2420 - val_accuracy: 0.9279
# Epoch 3/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2534 - accuracy: 0.9259 - val_loss: 0.2249 - val_accuracy: 0.9350
# Epoch 4/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2322 - accuracy: 0.9319 - val_loss: 0.1960 - val_accuracy: 0.9403
# Epoch 5/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2188 - accuracy: 0.9356 - val_loss: 0.2269 - val_accuracy: 0.9311
# Epoch 6/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2084 - accuracy: 0.9384 - val_loss: 0.1936 - val_accuracy: 0.9452
# Epoch 7/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2049 - accuracy: 0.9398 - val_loss: 0.1911 - val_accuracy: 0.9448
# Epoch 8/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2013 - accuracy: 0.9394 - val_loss: 0.1819 - val_accuracy: 0.9462
# Epoch 9/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1938 - accuracy: 0.9429 - val_loss: 0.1869 - val_accuracy: 0.9457
# Epoch 10/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1864 - accuracy: 0.9449 - val_loss: 0.1763 - val_accuracy: 0.9498
# Epoch 11/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1830 - accuracy: 0.9453 - val_loss: 0.1800 - val_accuracy: 0.9465
# Epoch 12/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1773 - accuracy: 0.9474 - val_loss: 0.1801 - val_accuracy: 0.9488
# Epoch 13/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1769 - accuracy: 0.9477 - val_loss: 0.1698 - val_accuracy: 0.9491
# Epoch 14/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1728 - accuracy: 0.9481 - val_loss: 0.1673 - val_accuracy: 0.9530
# Epoch 15/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1681 - accuracy: 0.9506 - val_loss: 0.1782 - val_accuracy: 0.9473
# Epoch 16/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1674 - accuracy: 0.9506 - val_loss: 0.1705 - val_accuracy: 0.9513
# Epoch 17/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1621 - accuracy: 0.9523 - val_loss: 0.1704 - val_accuracy: 0.9523
# Epoch 18/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1635 - accuracy: 0.9519 - val_loss: 0.1691 - val_accuracy: 0.9509
# Epoch 19/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1591 - accuracy: 0.9536 - val_loss: 0.1721 - val_accuracy: 0.9515
# Epoch 20/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1593 - accuracy: 0.9532 - val_loss: 0.1703 - val_accuracy: 0.9524
# Epoch 21/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1557 - accuracy: 0.9531 - val_loss: 0.1709 - val_accuracy: 0.9507
# Epoch 22/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1554 - accuracy: 0.9536 - val_loss: 0.1760 - val_accuracy: 0.9491
# Epoch 23/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1546 - accuracy: 0.9538 - val_loss: 0.1715 - val_accuracy: 0.9506
# Epoch 24/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1530 - accuracy: 0.9536 - val_loss: 0.1689 - val_accuracy: 0.9527
# Epoch 25/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1511 - accuracy: 0.9545 - val_loss: 0.1763 - val_accuracy: 0.9480
# Epoch 26/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1496 - accuracy: 0.9541 - val_loss: 0.1680 - val_accuracy: 0.9538
# Epoch 27/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1499 - accuracy: 0.9549 - val_loss: 0.1723 - val_accuracy: 0.9514
# Epoch 28/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1484 - accuracy: 0.9554 - val_loss: 0.1692 - val_accuracy: 0.9508
# Epoch 29/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1491 - accuracy: 0.9559 - val_loss: 0.1699 - val_accuracy: 0.9522
# Epoch 30/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1472 - accuracy: 0.9558 - val_loss: 0.1724 - val_accuracy: 0.9514
# Epoch 31/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1468 - accuracy: 0.9555 - val_loss: 0.1714 - val_accuracy: 0.9518
# Epoch 32/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1427 - accuracy: 0.9568 - val_loss: 0.1656 - val_accuracy: 0.9534
# Epoch 33/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1451 - accuracy: 0.9560 - val_loss: 0.1709 - val_accuracy: 0.9518
# Epoch 34/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1428 - accuracy: 0.9563 - val_loss: 0.1738 - val_accuracy: 0.9524
# Epoch 35/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1425 - accuracy: 0.9566 - val_loss: 0.1761 - val_accuracy: 0.9477
# Epoch 36/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1423 - accuracy: 0.9569 - val_loss: 0.1819 - val_accuracy: 0.9490
# Epoch 37/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1393 - accuracy: 0.9583 - val_loss: 0.1699 - val_accuracy: 0.9535
# Epoch 38/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1412 - accuracy: 0.9571 - val_loss: 0.1699 - val_accuracy: 0.9509
# Epoch 39/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1392 - accuracy: 0.9587 - val_loss: 0.1697 - val_accuracy: 0.9516
# Epoch 40/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1414 - accuracy: 0.9569 - val_loss: 0.1719 - val_accuracy: 0.9497
# Epoch 41/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1387 - accuracy: 0.9572 - val_loss: 0.1693 - val_accuracy: 0.9518
# Epoch 42/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1390 - accuracy: 0.9567 - val_loss: 0.1704 - val_accuracy: 0.9517
# Epoch 43/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1375 - accuracy: 0.9580 - val_loss: 0.1815 - val_accuracy: 0.9483
# Epoch 44/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1371 - accuracy: 0.9577 - val_loss: 0.1705 - val_accuracy: 0.9529
# Epoch 45/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1381 - accuracy: 0.9578 - val_loss: 0.1738 - val_accuracy: 0.9512
# Epoch 46/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1368 - accuracy: 0.9589 - val_loss: 0.1702 - val_accuracy: 0.9530
# Epoch 47/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1369 - accuracy: 0.9579 - val_loss: 0.1696 - val_accuracy: 0.9539
# Epoch 48/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1364 - accuracy: 0.9573 - val_loss: 0.1735 - val_accuracy: 0.9539
# Epoch 49/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1331 - accuracy: 0.9593 - val_loss: 0.1709 - val_accuracy: 0.9530
# Epoch 50/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1348 - accuracy: 0.9595 - val_loss: 0.1729 - val_accuracy: 0.9518

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 0s 883us/step - loss: 0.1729 - accuracy: 0.9518
# [0.17292849719524384, 0.9517999887466431]

# %%
y_predicted = model.predict(X_test)
y_predicted_labels = [np.argmax(i) for i in y_predicted]

cm = tf.math.confusion_matrix(labels=y_test, predictions=y_predicted_labels)

import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(66.5, 0.5, 'Truth')

# %%
fig = plt.figure()
plt.subplot(2,1,1)
plt.plot(model2.history['accuracy'])
plt.plot(model2.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

plt.subplot(2,1,2)
plt.plot(model2.history['loss'])
plt.plot(model2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.tight_layout()

# %%
model = Sequential()

model.add(Dense(10, input_shape=(784,)))
model.add(Dense(15, activation='relu'))
model.add(BatchNormalization())
model.add(layers.Dropout(0.01))
model.add(Dense(10, activation='sigmoid'))

# Impression d'une description du réseau
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 10)                7850
# _________________________________________________________________
# dense_16 (Dense)             (None, 15)                165
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 15)                60
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 15)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 10)                160
# =================================================================
# Total params: 8,235
# Trainable params: 8,205
# Non-trainable params: 30
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model2 = model.fit(X_train, y_train, epochs=50, batch_size= 32 , validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.7835 - accuracy: 0.8112 - val_loss: 0.2989 - val_accuracy: 0.9142
# Epoch 2/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3305 - accuracy: 0.9051 - val_loss: 0.2590 - val_accuracy: 0.9240
# Epoch 3/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2978 - accuracy: 0.9128 - val_loss: 0.2650 - val_accuracy: 0.9227
# Epoch 4/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2825 - accuracy: 0.9169 - val_loss: 0.2356 - val_accuracy: 0.9298
# Epoch 5/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2699 - accuracy: 0.9202 - val_loss: 0.2235 - val_accuracy: 0.9341
# Epoch 6/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2617 - accuracy: 0.9229 - val_loss: 0.2259 - val_accuracy: 0.9320
# Epoch 7/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2547 - accuracy: 0.9243 - val_loss: 0.2213 - val_accuracy: 0.9336
# Epoch 8/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2465 - accuracy: 0.9258 - val_loss: 0.2062 - val_accuracy: 0.9395
# Epoch 9/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2394 - accuracy: 0.9283 - val_loss: 0.2151 - val_accuracy: 0.9375
# Epoch 10/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2381 - accuracy: 0.9286 - val_loss: 0.2057 - val_accuracy: 0.9389
# Epoch 11/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2331 - accuracy: 0.9315 - val_loss: 0.2162 - val_accuracy: 0.9369
# Epoch 12/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2275 - accuracy: 0.9323 - val_loss: 0.2020 - val_accuracy: 0.9423
# Epoch 13/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2266 - accuracy: 0.9322 - val_loss: 0.2135 - val_accuracy: 0.9390
# Epoch 14/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2271 - accuracy: 0.9315 - val_loss: 0.2090 - val_accuracy: 0.9372
# Epoch 15/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2203 - accuracy: 0.9345 - val_loss: 0.2032 - val_accuracy: 0.9392
# Epoch 16/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2191 - accuracy: 0.9341 - val_loss: 0.1982 - val_accuracy: 0.9429
# Epoch 17/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2193 - accuracy: 0.9342 - val_loss: 0.1984 - val_accuracy: 0.9428
# Epoch 18/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2132 - accuracy: 0.9355 - val_loss: 0.1969 - val_accuracy: 0.9434
# Epoch 19/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2117 - accuracy: 0.9361 - val_loss: 0.2104 - val_accuracy: 0.9389
# Epoch 20/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2095 - accuracy: 0.9369 - val_loss: 0.2099 - val_accuracy: 0.9406
# Epoch 21/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2067 - accuracy: 0.9368 - val_loss: 0.1901 - val_accuracy: 0.9466
# Epoch 22/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2097 - accuracy: 0.9363 - val_loss: 0.1874 - val_accuracy: 0.9455
# Epoch 23/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2075 - accuracy: 0.9370 - val_loss: 0.1915 - val_accuracy: 0.9456
# Epoch 24/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2043 - accuracy: 0.9386 - val_loss: 0.1928 - val_accuracy: 0.9447
# Epoch 25/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2016 - accuracy: 0.9387 - val_loss: 0.1958 - val_accuracy: 0.9441
# Epoch 26/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2024 - accuracy: 0.9382 - val_loss: 0.1897 - val_accuracy: 0.9450
# Epoch 27/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2016 - accuracy: 0.9391 - val_loss: 0.1890 - val_accuracy: 0.9455
# Epoch 28/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2009 - accuracy: 0.9395 - val_loss: 0.1858 - val_accuracy: 0.9477
# Epoch 29/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1983 - accuracy: 0.9400 - val_loss: 0.1888 - val_accuracy: 0.9466
# Epoch 30/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1974 - accuracy: 0.9404 - val_loss: 0.1899 - val_accuracy: 0.9442
# Epoch 31/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1979 - accuracy: 0.9405 - val_loss: 0.1851 - val_accuracy: 0.9475
# Epoch 32/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1969 - accuracy: 0.9406 - val_loss: 0.1915 - val_accuracy: 0.9465
# Epoch 33/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1951 - accuracy: 0.9406 - val_loss: 0.1874 - val_accuracy: 0.9463
# Epoch 34/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1933 - accuracy: 0.9412 - val_loss: 0.1981 - val_accuracy: 0.9444
# Epoch 35/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1945 - accuracy: 0.9417 - val_loss: 0.1828 - val_accuracy: 0.9476
# Epoch 36/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1934 - accuracy: 0.9420 - val_loss: 0.1851 - val_accuracy: 0.9460
# Epoch 37/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1913 - accuracy: 0.9426 - val_loss: 0.1868 - val_accuracy: 0.9493
# Epoch 38/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1913 - accuracy: 0.9420 - val_loss: 0.1801 - val_accuracy: 0.9498
# Epoch 39/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1915 - accuracy: 0.9418 - val_loss: 0.1890 - val_accuracy: 0.9465
# Epoch 40/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1882 - accuracy: 0.9436 - val_loss: 0.1880 - val_accuracy: 0.9477
# Epoch 41/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1911 - accuracy: 0.9426 - val_loss: 0.1838 - val_accuracy: 0.9496
# Epoch 42/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1900 - accuracy: 0.9431 - val_loss: 0.1801 - val_accuracy: 0.9503
# Epoch 43/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1901 - accuracy: 0.9426 - val_loss: 0.1881 - val_accuracy: 0.9469
# Epoch 44/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1880 - accuracy: 0.9420 - val_loss: 0.1801 - val_accuracy: 0.9502
# Epoch 45/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1869 - accuracy: 0.9431 - val_loss: 0.1814 - val_accuracy: 0.9506
# Epoch 46/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1896 - accuracy: 0.9428 - val_loss: 0.1806 - val_accuracy: 0.9491
# Epoch 47/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1851 - accuracy: 0.9434 - val_loss: 0.1918 - val_accuracy: 0.9454
# Epoch 48/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1875 - accuracy: 0.9422 - val_loss: 0.1813 - val_accuracy: 0.9496
# Epoch 49/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1865 - accuracy: 0.9435 - val_loss: 0.1785 - val_accuracy: 0.9502
# Epoch 50/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1850 - accuracy: 0.9436 - val_loss: 0.1845 - val_accuracy: 0.9470

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 0s 774us/step - loss: 0.1845 - accuracy: 0.9470
# [0.1845380663871765, 0.9470000267028809]

# %%
y_predicted = model.predict(X_test)
y_predicted_labels = [np.argmax(i) for i in y_predicted]

cm = tf.math.confusion_matrix(labels=y_test, predictions=y_predicted_labels)

import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(66.5, 0.5, 'Truth')

# %%
fig = plt.figure()
plt.subplot(2,1,1)
plt.plot(model2.history['accuracy'])
plt.plot(model2.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

plt.subplot(2,1,2)
plt.plot(model2.history['loss'])
plt.plot(model2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.tight_layout()

# %% [markdown]
# 8. Surveillez le surapprentissage de vos modèles en visualisant la loss en fonction des epochs. S’il y a du surapprentissage, utilisez des couches de régularisation.

# %%
model = Sequential()

model.add(Dense(10, input_shape=(784,)))
model.add(layers.Dropout(0.005))
model.add(Dense(15, activation='relu'))
model.add(BatchNormalization())
model.add(layers.Dropout(0.005))
model.add(Dense(10, activation='sigmoid'))

# Impression d'une description du réseau
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 10)                7850
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 15)                165
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 15)                60
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 15)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                160
# =================================================================
# Total params: 8,235
# Trainable params: 8,205
# Non-trainable params: 30
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# Define early_stopping_monitor
early_stopping_monitor = EarlyStopping(patience=5)
tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=10, verbose=1, mode="auto")

# Fit the model
model3=model.fit(X_train, y_train, epochs=30, validation_split=0.3, validation_data=(X_test, y_test), callbacks=[early_stopping_monitor])
# Out:
# Epoch 1/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.2028 - accuracy: 0.9383 - val_loss: 0.2234 - val_accuracy: 0.9344
# Epoch 2/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.2067 - accuracy: 0.9364 - val_loss: 0.2239 - val_accuracy: 0.9355
# Epoch 3/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.2041 - accuracy: 0.9370 - val_loss: 0.2214 - val_accuracy: 0.9354
# Epoch 4/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.2042 - accuracy: 0.9376 - val_loss: 0.2233 - val_accuracy: 0.9343
# Epoch 5/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.2025 - accuracy: 0.9384 - val_loss: 0.2238 - val_accuracy: 0.9342
# Epoch 6/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.2019 - accuracy: 0.9371 - val_loss: 0.2226 - val_accuracy: 0.9360
# Epoch 7/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.2014 - accuracy: 0.9391 - val_loss: 0.2151 - val_accuracy: 0.9359
# Epoch 8/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.2037 - accuracy: 0.9367 - val_loss: 0.2230 - val_accuracy: 0.9337
# Epoch 9/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.2014 - accuracy: 0.9385 - val_loss: 0.2284 - val_accuracy: 0.9334
# Epoch 10/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.1991 - accuracy: 0.9385 - val_loss: 0.2203 - val_accuracy: 0.9356
# Epoch 11/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.1979 - accuracy: 0.9403 - val_loss: 0.2228 - val_accuracy: 0.9348
# Epoch 12/30
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.1969 - accuracy: 0.9396 - val_loss: 0.2281 - val_accuracy: 0.9332

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 0s 832us/step - loss: 0.2104 - accuracy: 0.9392
# [0.21044324338436127, 0.9391999840736389]

# %%
y_predicted = model.predict(X_test)
y_predicted_labels = [np.argmax(i) for i in y_predicted]

cm = tf.math.confusion_matrix(labels=y_test, predictions=y_predicted_labels)

import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(66.5, 0.5, 'Truth')

# %%
fig = plt.figure()
plt.subplot(2,1,1)
plt.plot(model3.history['accuracy'])
plt.plot(model3.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

plt.subplot(2,1,2)
plt.plot(model3.history['loss'])
plt.plot(model3.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.tight_layout()
